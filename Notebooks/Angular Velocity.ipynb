# %%
from miscpy.utils.sympyhelpers import *
init_printing()

# %% [markdown]
# # Euler Angles and Angular Velocity

# %%
aCi = rotMat(3,psi)
cCa = rotMat(2,th)
bCc = rotMat(3,ph)
aCi,cCa,bCc
# Out:
# ⎛⎡cos(ψ)   sin(ψ)  0⎤  ⎡cos(θ)  0  -sin(θ)⎤  ⎡cos(φ)   sin(φ)  0⎤⎞
# ⎜⎢                  ⎥  ⎢                  ⎥  ⎢                  ⎥⎟
# ⎜⎢-sin(ψ)  cos(ψ)  0⎥, ⎢  0     1     0   ⎥, ⎢-sin(φ)  cos(φ)  0⎥⎟
# ⎜⎢                  ⎥  ⎢                  ⎥  ⎢                  ⎥⎟
# ⎝⎣   0       0     1⎦  ⎣sin(θ)  0  cos(θ) ⎦  ⎣   0       0     1⎦⎠

# %%
bCi = bCc*cCa*aCi; bCi #3-2-3 rotation
# Out:
# ⎡-sin(φ)⋅sin(ψ) + cos(φ)⋅cos(ψ)⋅cos(θ)  sin(φ)⋅cos(ψ) + sin(ψ)⋅cos(φ)⋅cos(θ)
# ⎢
# ⎢-sin(φ)⋅cos(ψ)⋅cos(θ) - sin(ψ)⋅cos(φ)  -sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ)
# ⎢
# ⎣            sin(θ)⋅cos(ψ)                          sin(ψ)⋅sin(θ)
#
#  -sin(θ)⋅cos(φ)⎤
#                ⎥
#  sin(φ)⋅sin(θ) ⎥
#                ⎥
#      cos(θ)    ⎦

# %%
bCi_dot = difftotalmat(bCi,t,{th:thd,psi:psid,ph:phd});
bCi_dot
# Out:
# ⎡-φ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - φ̇⋅sin(ψ)⋅cos(φ) - ψ̇⋅sin(φ)⋅cos(ψ) - ψ̇⋅sin(ψ)⋅co
# ⎢
# ⎢φ̇⋅sin(φ)⋅sin(ψ) - φ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) + ψ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) - ψ̇⋅cos
# ⎢
# ⎣                                       -ψ̇⋅sin(ψ)⋅sin(θ) + θ̇⋅cos(ψ)⋅cos(θ)
#
# s(φ)⋅cos(θ) - θ̇⋅sin(θ)⋅cos(φ)⋅cos(ψ)  -φ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) + φ̇⋅cos(φ)⋅co
#
# (φ)⋅cos(ψ) + θ̇⋅sin(φ)⋅sin(θ)⋅cos(ψ)   -φ̇⋅sin(φ)⋅cos(ψ) - φ̇⋅sin(ψ)⋅cos(φ)⋅co
#
#
#
# s(ψ) - ψ̇⋅sin(φ)⋅sin(ψ) + ψ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) - θ̇⋅sin(ψ)⋅sin(θ)⋅cos(φ)  φ
#
# s(θ) - ψ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - ψ̇⋅sin(ψ)⋅cos(φ) + θ̇⋅sin(φ)⋅sin(ψ)⋅sin(θ)  φ
#
# ψ̇⋅sin(θ)⋅cos(ψ) + θ̇⋅sin(ψ)⋅cos(θ)
#
# ̇⋅sin(φ)⋅sin(θ) - θ̇⋅cos(φ)⋅cos(θ)⎤
#                                   ⎥
# ̇⋅sin(θ)⋅cos(φ) + θ̇⋅sin(φ)⋅cos(θ)⎥
#                                   ⎥
#            -θ̇⋅sin(θ)             ⎦

# %%
omega_tilde = bCi*bCi_dot.T; omega_tilde
# Out:
# ⎡
# ⎢(-sin(φ)⋅sin(ψ) + cos(φ)⋅cos(ψ)⋅cos(θ))⋅(-φ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - φ̇⋅sin(ψ)
# ⎢
# ⎢
# ⎢(φ̇⋅sin(φ)⋅sin(θ) - θ̇⋅cos(φ)⋅cos(θ))⋅sin(φ)⋅sin(θ) + (-sin(φ)⋅sin(ψ)⋅cos(θ)
# ⎢
# ⎣                             (φ̇⋅sin(φ)⋅sin(θ) - θ̇⋅cos(φ)⋅cos(θ))⋅cos(θ) + (
#
#
# ⋅cos(φ) - ψ̇⋅sin(φ)⋅cos(ψ) - ψ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ) - θ̇⋅sin(θ)⋅cos(φ)⋅cos(ψ)
#
#
# + cos(φ)⋅cos(ψ))⋅(-φ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) + φ̇⋅cos(φ)⋅cos(ψ) - ψ̇⋅sin(φ)⋅sin(
#
# -φ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) + φ̇⋅cos(φ)⋅cos(ψ) - ψ̇⋅sin(φ)⋅sin(ψ) + ψ̇⋅cos(φ)⋅cos
#
#
# ) + (sin(φ)⋅cos(ψ) + sin(ψ)⋅cos(φ)⋅cos(θ))⋅(-φ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) + φ̇⋅cos(
#
#
# ψ) + ψ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) - θ̇⋅sin(ψ)⋅sin(θ)⋅cos(φ)) + (-sin(φ)⋅cos(ψ)⋅cos(
#
# (ψ)⋅cos(θ) - θ̇⋅sin(ψ)⋅sin(θ)⋅cos(φ))⋅sin(ψ)⋅sin(θ) + (-φ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ
#
#
# φ)⋅cos(ψ) - ψ̇⋅sin(φ)⋅sin(ψ) + ψ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) - θ̇⋅sin(ψ)⋅sin(θ)⋅cos(
#
#
# θ) - sin(ψ)⋅cos(φ))⋅(-φ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - φ̇⋅sin(ψ)⋅cos(φ) - ψ̇⋅sin(φ)⋅c
#
# ) - φ̇⋅sin(ψ)⋅cos(φ) - ψ̇⋅sin(φ)⋅cos(ψ) - ψ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ) - θ̇⋅sin(θ)⋅
#
#
# φ)) - (φ̇⋅sin(φ)⋅sin(θ) - θ̇⋅cos(φ)⋅cos(θ))⋅sin(θ)⋅cos(φ)   (-sin(φ)⋅sin(ψ) +
#
#
# os(ψ) - ψ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ) - θ̇⋅sin(θ)⋅cos(φ)⋅cos(ψ))  (φ̇⋅sin(θ)⋅cos(φ)
#
# cos(φ)⋅cos(ψ))⋅sin(θ)⋅cos(ψ)
#
#
# cos(φ)⋅cos(ψ)⋅cos(θ))⋅(φ̇⋅sin(φ)⋅sin(ψ) - φ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) + ψ̇⋅sin(φ)⋅
#
#
# + θ̇⋅sin(φ)⋅cos(θ))⋅sin(φ)⋅sin(θ) + (-sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ))⋅(-
#
#            (φ̇⋅sin(θ)⋅cos(φ) + θ̇⋅sin(φ)⋅cos(θ))⋅cos(θ) + (φ̇⋅sin(φ)⋅sin(ψ) -
#
#
# sin(ψ)⋅cos(θ) - ψ̇⋅cos(φ)⋅cos(ψ) + θ̇⋅sin(φ)⋅sin(θ)⋅cos(ψ)) + (sin(φ)⋅cos(ψ) +
#
#
# φ̇⋅sin(φ)⋅cos(ψ) - φ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ) - ψ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - ψ̇⋅sin(
#
# φ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) + ψ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) - ψ̇⋅cos(φ)⋅cos(ψ) + θ̇⋅sin(
#
#
#  sin(ψ)⋅cos(φ)⋅cos(θ))⋅(-φ̇⋅sin(φ)⋅cos(ψ) - φ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ) - ψ̇⋅sin(φ
#
#
# ψ)⋅cos(φ) + θ̇⋅sin(φ)⋅sin(ψ)⋅sin(θ)) + (-sin(φ)⋅cos(ψ)⋅cos(θ) - sin(ψ)⋅cos(φ))
#
# φ)⋅sin(θ)⋅cos(ψ))⋅sin(θ)⋅cos(ψ) + (-φ̇⋅sin(φ)⋅cos(ψ) - φ̇⋅sin(ψ)⋅cos(φ)⋅cos(θ)
#
#
# )⋅cos(ψ)⋅cos(θ) - ψ̇⋅sin(ψ)⋅cos(φ) + θ̇⋅sin(φ)⋅sin(ψ)⋅sin(θ)) - (φ̇⋅sin(θ)⋅cos
#
#
# ⋅(φ̇⋅sin(φ)⋅sin(ψ) - φ̇⋅cos(φ)⋅cos(ψ)⋅cos(θ) + ψ̇⋅sin(φ)⋅sin(ψ)⋅cos(θ) - ψ̇⋅co
#
#  - ψ̇⋅sin(φ)⋅cos(ψ)⋅cos(θ) - ψ̇⋅sin(ψ)⋅cos(φ) + θ̇⋅sin(φ)⋅sin(ψ)⋅sin(θ))⋅sin(ψ
#
#                                                2
# (φ) + θ̇⋅sin(φ)⋅cos(θ))⋅sin(θ)⋅cos(φ)    θ̇⋅sin (θ)⋅cos(φ) + (-sin(φ)⋅sin(ψ) +
#
#                                                        2
# s(φ)⋅cos(ψ) + θ̇⋅sin(φ)⋅sin(θ)⋅cos(ψ))  - θ̇⋅sin(φ)⋅sin (θ) + (-ψ̇⋅sin(ψ)⋅sin(
#
# )⋅sin(θ)                                                           -θ̇⋅sin(θ)⋅
#
#
#  cos(φ)⋅cos(ψ)⋅cos(θ))⋅(-ψ̇⋅sin(ψ)⋅sin(θ) + θ̇⋅cos(ψ)⋅cos(θ)) + (sin(φ)⋅cos(ψ)
#
#
# θ) + θ̇⋅cos(ψ)⋅cos(θ))⋅(-sin(φ)⋅cos(ψ)⋅cos(θ) - sin(ψ)⋅cos(φ)) + (ψ̇⋅sin(θ)⋅co
#
# cos(θ) + (-ψ̇⋅sin(ψ)⋅sin(θ) + θ̇⋅cos(ψ)⋅cos(θ))⋅sin(θ)⋅cos(ψ) + (ψ̇⋅sin(θ)⋅cos
#
#                                                                 ⎤
#  + sin(ψ)⋅cos(φ)⋅cos(θ))⋅(ψ̇⋅sin(θ)⋅cos(ψ) + θ̇⋅sin(ψ)⋅cos(θ))  ⎥
#                                                                 ⎥
#                                                                 ⎥
# s(ψ) + θ̇⋅sin(ψ)⋅cos(θ))⋅(-sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ))⎥
#                                                                 ⎥
# (ψ) + θ̇⋅sin(ψ)⋅cos(θ))⋅sin(ψ)⋅sin(θ)                           ⎦

# %%
 simplify(Matrix([omega_tilde[2,1],omega_tilde[0,2],omega_tilde[1,0]]))
# Out:
# ⎡-ψ̇⋅sin(θ)⋅cos(φ) + θ̇⋅sin(φ)⎤
# ⎢                             ⎥
# ⎢ψ̇⋅sin(φ)⋅sin(θ) + θ̇⋅cos(φ) ⎥
# ⎢                             ⎥
# ⎣       φ̇ + ψ̇⋅cos(θ)        ⎦
